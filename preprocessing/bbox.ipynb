# %%
import read_write_model
from pathlib import Path

MODEL_DIR = Path("../data/calculator/model/sparse")

# %%
cameras = read_write_model.read_cameras_binary(MODEL_DIR / "5/cameras.bin")
images = read_write_model.read_images_binary(MODEL_DIR / "5/images.bin")
points = read_write_model.read_points3D_binary(MODEL_DIR / "5/points3D.bin")

# %%
images
# Out:
# {696: Image(id=696, qvec=array([ 0.96860929, -0.04045209, -0.22886886, -0.08819701]), tvec=array([ 3.10112761, -0.41379813,  0.4517605 ]), camera_id=696, name='695.png', xys=array([[1329.87658691,  575.61676025],
#         [1010.31964111, 2060.46411133],
#         [1622.44689941, 2562.44287109],
#         ...,
#         [ 872.77960205, 2149.08886719],
#         [ 988.78381348, 1927.69335938],
#         [ 371.49310303, 2128.95898438]]), point3D_ids=array([-1, -1, -1, ..., -1, -1, -1])),
#  700: Image(id=700, qvec=array([ 0.98331026, -0.02844058, -0.16994538, -0.0584006 ]), tvec=array([ 0.84650484, -0.24200384, -0.02422544]), camera_id=701, name='700.png', xys=array([[ 945.1942749 , 1983.19555664],
#         [1599.68383789, 1681.97937012],
#         [1558.84899902, 2545.55615234],
#         ...,
#         [1380.28308105, 1825.59301758],
#         [ 579.45098877, 2443.71069336],
#         [ 462.62921143, 1869.9666748 ]]), point3D_ids=array([6898,   -1, 6370, ..., 4984, 4391, 5467])),
# ...

# %%
cameras
# Out:
# {696: Camera(id=696, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.49667025e+03, 1.08000000e+03, 1.92000000e+03, 8.38790242e-02])),
#  700: Camera(id=700, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.49913778e+03, 1.08000000e+03, 1.92000000e+03, 7.98521424e-02])),
#  704: Camera(id=704, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.51614881e+03, 1.08000000e+03, 1.92000000e+03, 6.98227890e-02])),
#  708: Camera(id=708, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.52073295e+03, 1.08000000e+03, 1.92000000e+03, 6.02278259e-02])),
#  691: Camera(id=691, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.48685893e+03, 1.08000000e+03, 1.92000000e+03, 9.50782712e-02])),
#  693: Camera(id=693, model='SIMPLE_RADIAL', width=2160, height=3840, params=array([3.48791569e+03, 1.08000000e+03, 1.92000000e+03, 9.07147604e-02])),
# ...
